# %%
from PIL import Image
pil_im = Image.open('data/empire.jpg')
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=569x800 at 0x10C6FF310>

# %%
pil_im = Image.open('data/empire.jpg').convert('L')
pil_im
# Out:
# <PIL.Image.Image image mode=L size=569x800 at 0x1040A3D90>

# %%
# 1.1.1 画像のファイル形式変換
import os

# %%
filelist = ['foo.jpg', 'bar.bmp', 'zot.png']

# %%
for infile in filelist:
    outfile = os.path.splitext(infile)[0] + '.jpg'
    if infile != outfile:
        try:
            Image.open(infile).save(outfile)
        except:
            print "cannot convert", infile
# Out:
# cannot convert bar.bmp
# cannot convert zot.png

# %%
import imtools
filelist = imtools.get_imlist('./data')
filelist

# %%
# 1.1.2 サムネイルの作成
pil_im = Image.open('data/empire.jpg')
pil_im.thumbnail((128, 128))
pil_im

# %%
# 1.1.3 領域のコピーと貼りつけ
pil_im = Image.open('data/empire.jpg')
box = (100, 100, 400, 400)
region = pil_im.crop(box)
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x10D9309D0>

# %%
region = region.transpose(Image.ROTATE_180)
pil_im.paste(region, box)
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=569x800 at 0x10E5E3850>

# %%
# 拡大縮小と回転
pil_im = Image.open('data/empire.jpg')
out = pil_im.resize((128, 128))
out
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x10C6F4890>

# %%
pil_im = Image.open('data/empire.jpg')
out = pil_im.rotate(45)
out
# Out:
# <PIL.Image.Image image mode=RGB size=569x800 at 0x10C705B50>
